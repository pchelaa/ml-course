# %% [markdown]
# # Topic Modeling and Gibbs Sampling

# %% [markdown]
# Задача: описать текст через распределение весов по некоторому фиксированному набору топиков (тегов). Например, для набора тегов Политика, Военные сражения, Спорт, Интернет, Драма представить роман "Война и мир" как вектор (0.3, 0.2, 0, 0, 0.5), а статью в газете про допинг в велоспорте как вектор (0.1, 0, 0.7, 0, 0.2).
#
# Для чего, например, это нужно: имея векторное представление для текстов, тексты можно сравнивать, рекомендовать похожие.
#
# Условие: даны только набор текстов и количество тем.

# %% [markdown]
# ## Немного теории

# %% [markdown]
# Будем представлять текст как неупорядоченный набор слов (Bag-of-words model). Предположим, что имеется K тегов и для каждого тега выбрано распределение $\phi_k$ над списком всевозможных слов (словарем из N слов). По сути, каждое $\phi_k$ - это вектор длины N из неотрицательных величин, в сумме дающих 1. Вектора $\phi_k$ независимы и моделируются распредеделением Дирихле $Dir(\beta)$. Теперь, чтобы собрать текст d из $n$ слов, будем действовать по следующей схеме:
#
#
# * выберем распредление для тегов $\theta_d$. Вновь, $\theta_d$ - это вектор длины K из неотрицательных величин, в сумме дающих 1. Поэтому естественно брать $\theta_d \sim Dir(\theta | \alpha)$
#
# * Для i от 1 до n:
#   * выберем тег $z_i$ согласно распределению $\theta_d$
#   * выберем слово $w_i$ из распределения для данного тега, т.е. $w_i \sim \phi_{z_i}$
#   * добавляем слово $w_i$ в текст.
#
# Полученная модель называется моделью LDA (Latent Dirichlet Allocation). Описанная  схема задает совместное распределение скрытых и наблюдаемых параметров по всем текстам корпуса размера M в виде:
#
#
# $p(\textbf{w}, \textbf{z}, \theta, \phi | \alpha, \beta) = Dir(\theta | \alpha) Dir(\phi|\beta)Cat(\textbf{z}|\theta)Cat(\textbf{w}|\phi_z)$.
#
# Здесь $\textbf{w}$ и $\textbf{z}$ обозначают вектора слов и тегов по всем текстам, $\theta$ - набор из $\theta_d$ для каждого документа (матрица $M\times K$), $\phi$ - набор из $\phi_k$ для каждого тега (матрица $K\times N$).

# %% [markdown]
# ![img](https://www.researchgate.net/publication/336065245/figure/fig1/AS:807371718815752@1569503826964/Latent-Dirichlet-allocation-LDA-process-and-its-two-outputs-a-LDA-document.ppm)

# %% [markdown]
# Наша задача - восстановить распределение $p(\textbf{z}, \theta, \phi | \textbf{w}, \alpha, \beta)$.
#
#
# Немного упростим жизнь, и поставим себе задачей восстановить распределение $p(\textbf{z} | \textbf{w}, \alpha, \beta) = \int\int p(\textbf{z}, \theta, \phi | \textbf{w}, \alpha, \beta)\textrm{d}\theta\textrm{d}\phi$.
#
# В этот момент на помощь приходить алгоритм Gibbs Sampling. Напомним, для оценки набора парамеров $\textbf{z} = (z_1, z_2, ..., z_m)$ используется схема:
#
# $z_i^{(t)} \sim p(z_i^{(t)}\ | \ z_1=z_1^{t}, ..., z_{i-1}=z_{i-1}^{t},
# z_{i+1}=z_{i+1}^{t-1}, z_{m}=z_{m}^{t-1})$.

# %% [markdown]
# Условные распределения выводятся так. Сначала замечаем, что
#
# $p(z_i|\textbf{z}_{\hat{i}}, \textbf{w}, \alpha, \beta) = \frac{p(z_i,\textbf{z}_{\hat{i}}, \textbf{w}| \alpha, \beta)}{p(\textbf{z}_{\hat{i}}, \textbf{w}| \alpha, \beta)}  = \frac{p(\textbf{z}, \textbf{w}| \alpha, \beta)}{p(\textbf{z}_{\hat{i}}, \textbf{w}| \alpha, \beta)}$.
#
# Здесь $\textbf{z}_{\hat{i}}$ - вектор без $i$-oй копмоненты.

# %% [markdown]
# Далее расписываем:
#
# $p(\textbf{z}, \textbf{w}| \alpha, \beta) = \int\int p(\textbf{z}, \textbf{w}, \theta, \phi| \alpha, \beta)\textrm{d}\theta\textrm{d}\phi = \int\int Dir(\theta | \alpha) Dir(\phi|\beta)Cat(\textbf{z}|\theta)Cat(\textbf{w}|\phi_z)\textrm{d}\theta\textrm{d}\phi =
# \int Dir(\theta | \alpha) Cat(\textbf{z}|\theta)\textrm{d}\theta \int Dir(\phi|\beta)Cat(\textbf{w}|\phi_z)\textrm{d}\phi$
#
# и обнаруживаем, что оба интеграла в последнем выражении вычисляются аналитически. Для примера первый:
#
# $\int Dir(\theta | \alpha) Cat(\textbf{z}|\theta)\textrm{d}\theta = \prod\limits_d \int Dir(\theta_d | \alpha) Cat(\textbf{z}_d|\theta_d)\textrm{d}\theta_d = \prod\limits_d \int \frac{1}{B(\alpha)}\prod\limits_k \theta_{d, k}^{\alpha-1}\prod\limits_i \theta_{d, z_i}\textrm{d}\theta_d = \prod\limits_d\frac{1}{B(\alpha)}\int\prod\limits_k \theta_{d, k}^{n_{d, k} + \alpha - 1}\textrm{d}\theta_d = \prod\limits_d \frac{B(n_{d,\cdot} + \alpha)}{B(\alpha)}$.
#
# Здесь  $n_{d,k}$ - количество тэгов $k$ в тексте $d$, $n_{d,\cdot}$ - вектор длины $K$ из этих величин.
#
# Аналогично, второй интеграл
# $\int Dir(\phi|\beta)Cat(\textbf{w}|\phi_z)\textrm{d}\phi = \prod\limits_k \frac{B(n_{k,\cdot} + \beta)}{B(\beta)}$,
#
# где $n_{k,\cdot}$ - вектор длины $N$ встречаемости слов внутри тэга $k$.
#
# Получаем:
#
# $p(\textbf{z}, \textbf{w}| \alpha, \beta) =\prod\limits_d \frac{B(n_{d,\cdot} + \alpha)}{B(\alpha)} \prod\limits_k \frac{B(n_{k,\cdot} + \beta)}{B(\beta)}$.
#
# Теперь
# $p(z_i|\textbf{z}_{\hat{i}}, \textbf{w}, \alpha, \beta) = \prod\limits_d \frac{B(n_{d,\cdot} + \alpha)}{B(n_{d,\cdot}^{\hat{i}} + \alpha)} \prod\limits_k \frac{B(n_{k,\cdot} + \beta)}{B(n_{k,\cdot}^{\hat{i}} + \beta)}$.
#
# Выражение упрощается дальше, расписывая бета-функцию через гамма-функции. Напомним,
# $B(x_1, ..., x_k) = \frac{\Gamma(x_1)\cdot...\cdot\Gamma(x_k)}{\Gamma(x_1 + ... + x_k)}$, а также $\Gamma(n) = (n-1)\Gamma(n-1)$. Получим:
#
# $p(z_i=s|\textbf{z}_{\hat{i}}, \textbf{w}, \alpha, \beta) \propto (n_{d, s} + \alpha_s - 1) \frac{n_{s, w_i} + \beta_s - 1}{\sum\limits_{w}(n_{s, w} + \beta_{w}) - 1}$.
#
# Знак $\propto$ означает пропорциональность с точностью до коэффициентов, независящих от $i$, $s$.

# %% [markdown]
# С этого места можно полностью собрать алгоритм моделирования плотности $p(\textbf{z}| \textbf{w}, \alpha, \beta)$. Введем  обозначение $n_k$ - количество слов, отнесенных к тегу $k$, $W$ - общее количество слов в корпусе, $\overline\beta=\sum\limits_w\beta_w$.
#
# Алгоритм:
#
# * заведем счетчики $n_{k, w}$, $n_{d, k}$, $n_k$
# * случайным образом расставим теги словам, обновим счетчики $n_{k, w}$, $n_{d, k}$, $n_k$
# * пока не сойдемся к стационарному режиму:
#   * для каждого $i$ от 1 до $W$:
#       * для каждого $k$ от 1 до $K$:
#         * вычисляем $p(z_i=k|...) = (n_{d, k} + \alpha_k - 1) \frac{n_{k, w_i} + \beta_k - 1}{n_k + \overline\beta - 1}$
#         * сэмплим новый $z_i$ из полученного распределения $p(z_i=k|...)$

# %% [markdown]
# Восстановив распредление для $\textbf{z}$, можем оценить $\theta$ и $\phi$, о которых мы ненадолго забыли. Оценить можно, например, через матожидание по апостериорным распределениям. Получите формулы самостоятельно!

# %% [markdown]
# Литература:
#
# http://u.cs.biu.ac.il/~89-680/darling-lda.pdf
#
# https://www.cs.cmu.edu/~mgormley/courses/10701-f16/slides/lecture20-topic-models.pdf

# %% [markdown]
# Перейдем к практике.

# %% [markdown]
# ## Датасет
#
# Возьмем популярный датасет [20 Newsgroups](http://qwone.com/~jason/20Newsgroups/), встроенный в пакет ```sklearn```. Датасет состоит из ~20К текстов, классифицированных на 20 категорий. Датасет разбит на ```train``` и ```test```. Для загрузки используем  модуль ```fetch_20newsgroups```, в параметрах указать, что мета информацию о тексте загружать не нужно:

# %%
import numpy as np
from sklearn.datasets import fetch_20newsgroups

newsgroups_train = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'))

# %% [markdown]
# Выведем список категорий текстов:

# %%
newsgroups_train.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %% [markdown]
# Атрибут ```traget``` хранит номера категорий для текстов из обучающей выборки:

# %%
newsgroups_train.target[:10]
# Out:
# array([ 7,  4,  4,  1, 14, 16, 13,  3,  2,  4])

# %% [markdown]
# Доступ к самим текстам через атрибут ```data```. Выведем текст и категорию случайного примера из обучающего датасета:

# %%
n = 854
print('Topic = {0}\n'.format(newsgroups_train.target_names[newsgroups_train.target[n]]))
print(newsgroups_train.data[n])
# Out:
# Topic = rec.motorcycles
#
# hey... I'm pretty new to the wonderful world of motorcycles... I just
# bought
# a used 81 Kaw KZ650 CSR from a friend.... I was just wondering what kind of
#
# saddle bags I could get for it (since I know nothing about them)  are there
# bags for the gas tank?  how much would some cost, and how much do they
# hold?
# thanks for your advice!!!  I may be new to riding, but I love it
# already!!!!
# :)

# %% [markdown]
# ## Векторное представление текста
#
# Представим текст как вектор индикаторов вхождений слов из некоторого словаря в текст. Это простейшая модель BOF.
#
# Сформируем словарь на основе нашего набора текстов. Для этого используем модуль ```CountVectorizer```:

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS

vectorizer = CountVectorizer(lowercase=True, stop_words=ENGLISH_STOP_WORDS,
                             analyzer='word', binary=True, min_df=10, max_df=.04)
vectorizer.fit(newsgroups_train.data)
# Out:
# CountVectorizer(analyzer='word', binary=True, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=0.04, max_features=None, min_df=10,
#                 ngram_range=(1, 1), preprocessor=None,
#                 stop_words=frozenset({'a', 'about', 'above', 'across', 'after',
#                                       'afterwards', 'again', 'against', 'all',
#                                       'almost', 'alone', 'along', 'already',
#                                       'also', 'although', 'always', 'am',
#                                       'among', 'amongst', 'amoungst', 'amount',
#                                       'an', 'and', 'another', 'any', 'anyhow',
#                                       'anyone', 'anything', 'anyway',
#                                       'anywhere', ...}),
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %% [markdown]
# Количество проиндексированных слов:

# %%
len(vectorizer.vocabulary_)
# Out:
# 10299

# %% [markdown]
# Проиндексированные слова и их индексы:

# %%
vectorizer.vocabulary_
# Out:
# {'wondering': 10138,
#  'enlighten': 3576,
#  'car': 1905,
#  'saw': 8221,
#  'door': 3288,
#  'sports': 8787,
#  'looked': 5726,
#  'late': 5506,
#  '60s': 542,
#  'early': 3399,
#  '70s': 593,
#  'doors': 3289,
#  'small': 8633,
#  'addition': 824,
#  'bumper': 1791,
#  'separate': 8381,
#  'rest': 7936,
#  'body': 1628,
#  'model': 6155,
#  'engine': 3560,
#  'specs': 8750,
#  'production': 7337,
#  'history': 4668,
#  'info': 4995,
#  'fair': 3856,
#  'brave': 1710,
#  'souls': 8705,
#  'upgraded': 9730,
#  'si': 8518,
#  'clock': 2185,
#  'oscillator': 6697,
#  'shared': 8445,
#  'experiences': 3762,
#  'poll': 7118,
#  'brief': 1731,
#  'message': 6021,
#  'detailing': 3061,
#  'procedure': 7318,
#  'speed': 8756,
#  'cpu': 2689,
#  'rated': 7616,
#  'add': 821,
#  'cards': 1912,
#  'adapters': 818,
#  'heat': 4598,
#  'hour': 4740,
#  'usage': 9748,
#  'floppy': 4047,
#  'disk': 3202,
#  'functionality': 4198,
#  '800': 620,
#  'floppies': 4046,
#  'especially': 3635,
#  'requested': 7883,
#  'days': 2867,
#  'network': 6398,
#  'knowledge': 5439,
#  'base': 1435,
#  'upgrade': 9729,
#  'haven': 4565,
#  'answered': 1066,
#  'folks': 4066,
#  'mac': 5801,
#  'plus': 7089,
#  'finally': 3980,
#  'gave': 4251,
#  'ghost': 4314,
#  'weekend': 10040,
#  'starting': 8845,
#  '512k': 502,
#  '1985': 204,
#  'market': 5891,
#  'machine': 5803,
#  'sooner': 8698,
#  'intended': 5091,
#  'picking': 6996,
#  'powerbook': 7183,
#  '160': 113,
#  '180': 138,
#  'bunch': 1792,
#  'questions': 7539,
#  'hopefully': 4719,
#  'somebody': 8688,
#  'answer': 1065,
#  'anybody': 1074,
#  'dirt': 3154,
#  'round': 8100,
#  'expected': 3752,
#  'supposed': 9076,
#  'summer': 9046,
#  'anymore': 1075,
#  'access': 752,
#  'rumors': 8131,
#  'price': 7276,
#  'drops': 3347,
#  'ones': 6615,
#  'duo': 3373,
#  'went': 10052,
#  'recently': 7684,
#  'impression': 4896,
#  'display': 3210,
#  'swing': 9129,
#  '80mb': 626,
#  '120': 60,
#  'feel': 3932,
#  'yea': 10250,
#  'looks': 5727,
#  'store': 8917,
#  'wow': 10174,
#  'opinions': 6640,
#  'worth': 10166,
#  'taking': 9176,
#  'size': 8583,
#  'money': 6184,
#  'hit': 4669,
#  'active': 803,
#  'realize': 7656,
#  'subjective': 8988,
#  'played': 7070,
#  'machines': 5804,
#  'computer': 2390,
#  'figured': 3963,
#  'uses': 9757,
#  'daily': 2822,
#  'prove': 7425,
#  'helpful': 4621,
#  'perform': 6923,
#  'advance': 858,
#  'summary': 9045,
#  'news': 6409,
#  'reading': 7646,
#  'premium': 7235,
#  'finals': 3981,
#  'corner': 2628,
#  'tom': 9412,
#  'willis': 10086,
#  'ecn': 3420,
#  'purdue': 7479,
#  'electrical': 3478,
#  'engineering': 3563,
#  'address': 828,
#  'phone': 6979,
#  'chip': 2076,
#  'article': 1198,
#  'std': 8870,
#  'baker': 1406,
#  'understanding': 9670,
#  'errors': 3623,
#  'basically': 1440,
#  'known': 5441,
#  'bugs': 1777,
#  'warning': 9985,
#  'checked': 2054,
#  'values': 9809,
#  'aren': 1151,
#  'till': 9378,
#  'launch': 5516,
#  'fix': 4012,
#  'code': 2223,
#  'possibly': 7161,
#  'introduce': 5147,
#  'crew': 2720,
#  'ok': 6602,
#  '213': 256,
#  'ignore': 4831,
#  'term': 9272,
#  'defined': 2948,
#  'doubt': 3298,
#  'quote': 7549,
#  'allegedly': 968,
#  'presenting': 7248,
#  'argument': 1162,
#  'weapons': 10028,
#  'mass': 5914,
#  'destruction': 3057,
#  'commonly': 2310,
#  'understood': 9671,
#  'switching': 9134,
#  'topics': 9428,
#  'evidently': 3681,
#  'allowed': 978,
#  'later': 5508,
#  'analysis': 1025,
#  'consider': 2478,
#  'class': 2149,
#  'responded': 7928,
#  'request': 7882,
#  'treatment': 9525,
#  'couldn': 2656,
#  'thank': 9307,
#  'directly': 3149,
#  'bouncing': 1681,
#  'sean': 8296,
#  'sharon': 8450,
#  'publicly': 7455,
#  'glad': 4333,
#  'accidentally': 759,
#  'rn': 8046,
#  'instead': 5058,
#  'rm': 8045,
#  'delete': 2964,
#  'file': 3966,
#  'september': 8388,
#  'hmmm': 4680,
#  'shows': 8511,
#  'scsi': 8284,
#  'controler': 2565,
#  'range': 7598,
#  '5mb': 529,
#  'controller': 2567,
#  '6mb': 583,
#  '10mb': 43,
#  'burst': 1804,
#  'note': 6466,
#  'increase': 4936,
#  'quadra': 7515,
#  'version': 9851,
#  'exist': 3733,
#  'pc': 6888,
#  'mode': 6154,
#  '16': 112,
#  'wide': 10071,
#  'fast': 3891,
#  '12mb': 73,
#  '20mb': 250,
#  '32': 376,
#  '40mb': 446,
#  'twice': 9598,
#  'esdi': 3633,
#  'correct': 2637,
#  'reach': 7633,
#  'faster': 3892,
#  'ide': 4809,
#  '96': 665,
#  'facts': 3846,
#  'posted': 7164,
#  'newsgroup': 6410,
#  'ibm': 4799,
#  'sheet': 8459,
#  'ftp': 4184,
#  'sumex': 9040,
#  'aim': 928,
#  'stanford': 8838,
#  '36': 407,
#  '44': 459,
#  'report': 7858,
#  'compare': 2327,
#  'txt': 9605,
#  '161': 115,
#  'documented': 3266,
#  'apple': 1102,
#  'maximum': 5942,
#  'synchronous': 9148,
#  'slower': 8627,
#  'interface': 5111,
#  'driven': 3337,
#  'win': 10088,
#  'downloaded': 3303,
#  'icons': 4805,
#  'bmp': 1614,
#  'figure': 3962,
#  'change': 2018,
#  'wallpaper': 9972,
#  'appreciated': 1116,
#  'thanx': 9309,
#  'board': 1620,
#  'licensing': 5632,
#  'technologies': 9234,
#  'owners': 6738,
#  'compression': 2381,
#  'technology': 9235,
#  'writing': 10187,
#  'memory': 6001,
#  'lost': 5742,
#  'reference': 7722,
#  'fault': 3900,
#  'icon': 4804,
#  'usually': 9761,
#  'mentioned': 6007,
#  'freeware': 4160,
#  'expansion': 3748,
#  'utility': 9767,
#  'dd': 2871,
#  'expand': 3745,
#  'compressed': 2380,
#  'unless': 9703,
#  'installed': 5053,
#  'product': 7336,
#  'unlikely': 9705,
#  'holes': 4691,
#  'related': 7775,
#  'fixed': 4013,
#  'sad': 8166,
#  'reluctant': 7802,
#  'buy': 1818,
#  'hey': 4640,
#  'competition': 2345,
#  '1978': 195,
#  'runs': 8135,
#  'paint': 6778,
#  'brown': 1755,
#  'orange': 6661,
#  'leaks': 5556,
#  'oil': 6599,
#  'pops': 7131,
#  '1st': 234,
#  'shop': 8488,
#  'trans': 9484,
#  'leak': 5555,
#  'sold': 8674,
#  'bike': 1547,
#  'owner': 6737,
#  'thinking': 9332,
#  '3k': 433,
#  'nice': 6421,
#  'stable': 8816,
#  'axis': 1369,
#  'motors': 6234,
#  'richardson': 8002,
#  'tx': 9604,
#  'org': 6673,
#  'dod': 3268,
#  'yep': 10257,
#  'jew': 5272,
#  'understand': 9668,
#  'jewish': 5273,
#  'jews': 5274,
#  'covenant': 2678,
#  'abraham': 720,
#  'moses': 6213,
#  'moral': 6202,
#  'follow': 4067,
#  'mankind': 5863,
#  'decide': 2895,
#  'boundaries': 1683,
#  'fall': 3864,
#  'believed': 1502,
#  'torah': 9431,
#  'required': 7887,
#  'pharisees': 6961,
#  'ancestors': 1029,
#  'modern': 6163,
#  'judaism': 5323,
#  'interpretation': 5128,
#  'lead': 5545,
#  'morality': 6203,
#  'essence': 3638,
#  'biblical': 1540,
#  'man': 5847,
#  'christian': 2093,
#  'necessarily': 6359,
#  'indicate': 4953,
#  'outside': 6721,
#  'relationship': 7780,
#  'speculate': 8753,
#  'trouble': 9559,
#  'created': 2708,
#  'image': 4851,
#  'conclusion': 2411,
#  'wants': 9978,
#  'script': 8276,
#  'foundation': 4131,
#  'mix': 6139,
#  'living': 5691,
#  'christ': 2092,
#  'jesus': 5269,
#  'recorded': 7699,
#  'followers': 4069,
#  'references': 7724,
#  'historians': 4663,
#  'revelation': 7970,
#  'aside': 1213,
#  'hand': 4508,
#  'worse': 10163,
#  'attempt': 1291,
#  'christianity': 2094,
#  'initially': 5014,
#  'bible': 1539,
#  'interpret': 5127,
#  'humanity': 4763,
#  'guess': 4461,
#  'faith': 3860,
#  'comes': 2278,
#  'inherent': 5008,
#  'absolute': 725,
#  'multiple': 6272,
#  'codes': 2225,
#  'founded': 4133,
#  'parent': 6815,
#  'child': 2070,
#  'swear': 9121,
#  'assume': 1248,
#  'simply': 8556,
#  'told': 9407,
#  'pub': 7450,
#  'bar': 1424,
#  'children': 2073,
#  'inappropriate': 4910,
#  'happy': 4533,
#  'animals': 1046,
#  'analogy': 1023,
#  'hold': 4685,
#  'water': 10007,
#  'knows': 5442,
#  'type': 9607,
#  'incidentally': 4916,
#  'young': 10268,
#  'considers': 2485,
#  'directive': 3148,
#  'gets': 4308,
#  'older': 6606,
#  'david': 2860,
#  'religion': 7799,
#  'description': 3030,
#  'external': 3812,
#  'tank': 9188,
#  'option': 6656,
#  'ssf': 8811,
#  'redesign': 7710,
#  'deleted': 2965,
#  'yo': 10266,
#  'ken': 5377,
#  'orbiter': 6664,
#  'options': 6658,
#  'today': 9402,
#  '23': 274,
#  'edition': 3434,
#  'york': 10267,
#  'reports': 7864,
#  'connor': 2466,
#  'panel': 6793,
#  'proposals': 7398,
#  'dropped': 3345,
#  'giant': 4316,
#  'fuel': 4188,
#  'tanks': 9189,
#  'launching': 5521,
#  'space': 8718,
#  'building': 1780,
#  'station': 8855,
#  'existing': 3738,
#  'shuttle': 8516,
#  'wings': 10097,
#  'tail': 9173,
#  'removed': 7826,
#  'currently': 2787,
#  'considered': 2483,
#  'presented': 7247,
#  'advisory': 873,
#  'meeting': 5985,
#  'yesterday': 10259,
#  'reported': 7859,
#  'low': 5754,
#  'cost': 2652,
#  'modular': 6171,
#  'approach': 1117,
#  'studied': 8973,
#  'team': 9222,
#  'teams': 9223,
#  'jsc': 5319,
#  'larc': 5494,
#  'supporting': 9072,
#  'crystal': 2759,
#  'city': 2131,
#  'lerc': 5595,
#  'reston': 7940,
#  'site': 8575,
#  'locations': 5708,
#  'helping': 4622,
#  'respective': 7924,
#  'activities': 806,
#  'key': 5386,
#  'features': 3920,
#  'bus': 1806,
#  'developed': 3078,
#  'lockheed': 5711,
#  'qualified': 7519,
#  'sts': 8968,
#  'provides': 7434,
#  'propulsion': 7405,
#  'gn': 4349,
#  'communications': 2314,
#  'management': 5850,
#  'air': 931,
#  'force': 4088,
#  'capability': 1892,
#  'obtained': 6551,
#  'flights': 4040,
#  'solar': 8672,
#  'arrays': 1185,
#  'provide': 7429,
#  'vehicle': 9831,
#  'arrow': 1195,
#  'environment': 3598,
#  'missions': 6124,
#  'utilize': 9768,
#  'source': 8711,
#  'human': 4761,
#  'tended': 9264,
#  'opposed': 6646,
#  'achieved': 784,
#  'common': 2309,
#  'module': 6173,
#  'modified': 6168,
#  'lab': 5459,
#  'ports': 7148,
#  'added': 822,
#  'international': 5124,
#  'partners': 6840,
#  'labs': 5467,
#  '60': 536,
#  'esa': 3627,
#  'modules': 6174,
#  'permanent': 6933,
#  'presence': 7243,
#  '3rd': 437,
#  'assured': 1256,
#  'return': 7960,
#  'freedom': 4155,
#  'derived': 3024,
#  'mike': 6068,
#  'alot': 982,
#  'design': 3037,
#  'love': 5749,
#  'assumes': 1250,
#  'assembly': 1226,
#  'computed': 2389,
#  '51': 499,
#  'inclination': 4918,
#  'orbit': 6662,
#  'build': 1778,
#  'occurs': 6566,
#  'initial': 5012,
#  'research': 7894,
#  'reached': 7634,
#  'transferred': 9489,
#  'visits': 9909,
#  'adopted': 853,
#  'language': 5491,
#  'deployed': 3012,
#  'keeping': 5372,
#  'supply': 9068,
#  'tolerance': 9408,
#  '14': 87,
#  '2nd': 351,
#  'thermal': 9328,
#  'control': 2564,
#  'radiator': 7574,
#  'finish': 3992,
#  '24': 284,
#  'systems': 9158,
#  'exception': 3700,
#  'major': 5836,
#  'changes': 2020,
#  'reduced': 7714,
#  'prices': 7278,
#  'forsale': 4116,
#  'behalf': 1490,
#  'brother': 1752,
#  'moving': 6249,
#  'moved': 6243,
#  'offer': 6582,
#  'black': 1581,
#  'portable': 7141,
#  'purchased': 7476,
#  '12': 59,
#  'sr': 8806,
#  '1000': 28,
#  'dual': 3362,
#  'cassette': 1938,
#  'player': 7071,
#  'fm': 4058,
#  'band': 1415,
#  'graphics': 4412,
#  'tape': 9191,
#  'deck': 2902,
#  'sound': 8706,
#  'bet': 1527,
#  '80': 619,
#  '25': 298,
#  'zoom': 10295,
#  'japan': 5252,
#  'includes': 4922,
#  'accessories': 756,
#  '50': 492,
#  '1400': 89,
#  'hair': 4497,
#  'head': 4578,
#  'bag': 1403,
#  'leather': 5563,
#  'brand': 1706,
#  'speeds': 8759,
#  'extra': 3814,
#  'angle': 1042,
#  'spray': 8790,
#  'steam': 8876,
#  'dry': 3354,
#  'iron': 5197,
#  'contact': 2519,
#  'reply': 7856,
#  'included': 4921,
#  'reasonable': 7663,
#  'happened': 4527,
#  'japanese': 5253,
#  'citizens': 2129,
#  'war': 9979,
#  'ii': 4835,
#  'prepared': 7239,
#  'stick': 8895,
#  'concentration': 2398,
#  'camp': 1870,
#  'trial': 9536,
#  'short': 8492,
#  'step': 8883,
#  'nazis': 6339,
#  'originally': 6688,
#  'final': 3979,
#  'solution': 8682,
#  'partly': 6838,
#  'afford': 892,
#  'camps': 1874,
#  'caused': 1957,
#  'total': 9441,
#  'weren': 10053,
#  'generally': 4272,
#  'died': 3111,
#  'disease': 3197,
#  'certainly': 1993,
#  'tiff': 9374,
#  'works': 10153,
#  'complexity': 2365,
#  'led': 5570,
#  'programs': 7355,
#  'poor': 7125,
#  'writers': 10185,
#  'making': 5842,
#  'bizarre': 1577,
#  'files': 3969,
#  'inability': 4907,
#  'load': 5697,
#  'images': 4853,
#  'save': 8215,
#  'general': 4270,
#  'environments': 3600,
#  'despite': 3052,
#  'saying': 8222,
#  'goes': 4362,
#  'worried': 10160,
#  'abuse': 732,
#  'immense': 4863,
#  'unnecessary': 9709,
#  'format': 4107,
#  'words': 10146,
#  'spec': 8735,
#  'page': 6771,
#  'emphasis': 3510,
#  'sort': 8701,
#  'success': 9009,
#  'designed': 3039,
#  'powerful': 7185,
#  'flexible': 4038,
#  'expense': 3757,
#  'simplicity': 8554,
#  'takes': 9175,
#  'effort': 3456,
#  'handle': 4515,
#  'specification': 8744,
#  'application': 1107,
#  'complete': 2360,
#  'job': 5282,
#  'import': 4887,
#  'generating': 4276,
#  'applications': 1108,
#  'deal': 2875,
#  'trapped': 9513,
#  'agrees': 919,
#  'reasoning': 7666,
#  'asking': 1215,
#  'rates': 7617,
#  'single': 8566,
#  'male': 5844,
#  'drivers': 3339,
#  'paying': 6881,
#  'performance': 6924,
#  'cars': 1930,
#  'replies': 7855,
#  'received': 7678,
#  '27': 320,
#  'close': 2189,
#  '1992': 212,
#  'dodge': 3269,
#  'stealth': 8875,
#  'rt': 8118,
#  'twin': 9599,
#  'turbo': 9584,
#  'tickets': 9370,
#  'accidents': 760,
#  'house': 4742,
#  'taken': 9174,
#  'defensive': 2943,
#  'driving': 3342,
#  'abs': 722,
#  'security': 8323,
#  'alarm': 944,
#  '1500': 101,
#  '500': 493,
#  'farm': 3885,
#  'insurance': 5073,
#  'additional': 825,
#  '100': 27,
#  '000': 1,
#  'policy': 7110,
#  'standard': 8832,
#  '300': 360,
#  'bought': 1676,
#  'company': 2323,
#  'accident': 757,
#  'ticket': 9369,
#  '11': 45,
#  'quoted': 7550,
#  'helps': 4624,
#  'steve': 8891,
#  'university': 9698,
#  '45': 461,
#  'kevin': 5385,
#  'remembered': 7816,
#  'correctly': 2641,
#  'asked': 1214,
#  'similar': 8544,
#  'situation': 8579,
#  'inquiry': 5035,
#  'age': 902,
#  'eagle': 3393,
#  'record': 7698,
#  'clean': 2159,
#  'illinois': 4845,
#  'turn': 9590,
#  '520': 509,
#  'higher': 4648,
#  'rate': 7615,
#  'couple': 2670,
#  'friends': 4174,
#  'pay': 6880,
#  'ins': 5037,
#  'companies': 2322,
#  'lucky': 5769,
#  'dan': 2832,
#  'mot': 6216,
#  'motorola': 6233,
#  'cellular': 1977,
#  '38': 417,
#  'usa': 9745,
#  'cc': 1964,
#  'live': 5687,
#  'oklahoma': 6604,
#  '89': 643,
#  'sc': 8225,
#  'claim': 2141,
#  'negligent': 6371,
#  'stop': 8912,
#  'signs': 8538,
#  'radios': 7579,
#  'violations': 9892,
#  '18': 137,
#  'months': 6196,
#  '85': 635,
#  '55': 513,
#  'failure': 3853,
#  'clear': 2164,
#  'intersection': 5136,
#  'damn': 2829,
#  'light': 5642,
#  'yellow': 10256,
#  '35': 398,
#  'passive': 6854,
#  'liability': 5615,
#  'comprehensive': 2378,
#  'collision': 2252,
#  'roughly': 8099,
#  '1300': 77,
#  '1100': 47,
#  '92': 660,
#  'lx': 5782,
#  'james': 5246,
#  'law': 5522,
#  'center': 1982,
#  'ucs': 9629,
#  'disclaimer': 3178,
#  'engineer': 3561,
#  'play': 7068,
#  'calls': 1862,
#  'thunder': 9366,
#  'bird': 1564,
#  'hell': 4615,
#  'killing': 5408,
#  'gonna': 4367,
#  '61': 543,
#  'experience': 3760,
#  'interesting': 5108,
#  'owned': 6736,
#  'toyota': 9455,
#  'gt': 4453,
#  'decided': 2896,
#  'gift': 4321,
#  'exotic': 3744,
#  'runners': 8133,
#  'porsche': 7139,
#  '1987': 206,
#  'liked': 5648,
#  'handling': 4519,
#  'appeal': 1092,
#  'personal': 6944,
#  'luxury': 5780,
#  'acceleration': 743,
#  'ready': 7650,
#  'buying': 1821,
#  'impulse': 4906,
#  'agent': 907,
#  'office': 6586,
#  'happen': 4526,
#  'classification': 2153,
#  'slight': 8615,
#  'newer': 6406,
#  'lower': 5756,
#  'risk': 8033,
#  'division': 3246,
#  'continue': 2540,
#  'account': 770,
#  'double': 3296,
#  'story': 8923,
#  'cover': 2679,
#  'cancel': 1882,
#  'sense': 8367,
#  'book': 1646,
#  'says': 8223,
#  'insure': 5074,
#  'traditional': 9473,
#  'conservative': 2476,
#  'eventually': 3675,
#  'reasons': 7667,
#  'dealer': 2876,
#  'tough': 9447,
#  'pressure': 7261,
#  'guy': 4479,
#  'room': 8088,
#  'equal': 3609,
#  'monthly': 6195,
#  'payments': 6885,
#  'longer': 5724,
#  'concluded': 2409,
#  'probability': 7313,
#  'auto': 1330,
#  'theft': 9311,
#  'entitled': 3591,
#  'opinion': 6639,
#  'oasys': 6518,
#  'dt': 3359,
#  'navy': 6337,
#  'mil': 6069,
#  'imagination': 4854,
#  'important': 4889,
#  'albert': 949,
#  'einstein': 3467,
#  'idaho': 4808,
#  '26': 312,
#  'turned': 9591,
#  'immediately': 4862,
#  'strictly': 8947,
#  'stayed': 8867,
#  '150': 100,
#  'pickup': 6998,
#  'amazing': 998,
#  'felt': 3942,
#  'responsible': 7935,
#  '21': 252,
#  'california': 1858,
#  'violation': 9891,
#  '2000': 241,
#  'bargain': 1428,
#  '28': 329,
#  'vw': 9948,
#  'san': 8188,
#  'jose': 5303,
#  'vs': 9944,
#  'v6': 9793,
#  '1986': 205,
#  'honda': 4708,
#  'mexico': 6038,
#  'town': 9452,
#  'nearby': 6353,
#  '5x': 535,
#  '2x': 359,
#  'insured': 5075,
#  'robert': 8051,
#  'stack': 8817,
#  'institute': 5059,
#  'transportation': 9511,
#  'studies': 8974,
#  'univ': 9693,
#  'uci': 9627,
#  'mazda': 5945,
#  '37': 413,
#  'saturn': 8212,
#  '64': 554,
#  'st': 8813,
#  'yearly': 10252,
#  'date': 2853,
#  'license': 5629,
#  'oct': 6568,
#  'residence': 7903,
#  'mountain': 6237,
#  'view': 9873,
#  '415': 450,
#  '962': 667,
#  '1200': 61,
#  'knock': 5435,
#  'wood': 10141,
#  'huge': 4757,
#  'difference': 3117,
#  'personally': 6946,
#  'towns': 9453,
#  'distance': 3219,
#  'boston': 1670,
#  'worst': 10165,
#  '600': 537,
#  '43': 455,
#  '1990': 210,
#  'mitsubishi': 6138,
#  'eclipse': 3419,
#  'chicago': 2067,
#  'coverage': 2680,
#  'discount': 3182,
#  'miles': 6074,
#  'lived': 5688,
#  '41': 447,
#  '93': 661,
#  'sho': 8481,
#  '287': 335,
#  'month': 6194,
#  'thats': 9310,
#  '100k': 29,
#  'property': 7388,
#  '250': 299,
#  'glass': 4335,
#  '39': 424,
#  'seriously': 8395,
#  'ripped': 8028,
#  'listed': 5675,
#  '2k': 346,
#  'calling': 1861,
#  'dealers': 2877,
#  'places': 7043,
#  'changed': 2019,
#  'maintain': 5831,
#  'careful': 1917,
#  'voltage': 9926,
#  'signal': 8529,
#  'output': 6715,
#  'preferably': 7223,
#  'factor': 3843,
#  'resulting': 7951,
#  'fed': 3923,
#  'easily': 3407,
#  'acquisition': 794,
#  'card': 1909,
#  'circuits': 2118,
#  'simple': 8551,
#  'amplifier': 1018,
#  'practice': 7194,
#  'sufficiently': 9025,
#  'nicely': 6422,
#  'degrees': 2957,
#  'accuracy': 775,
#  'exact': 3689,
#  'entry': 3595,
#  'parameter': 6809,
#  'syntax': 9150,
#  'terminal': 9273,
#  'configuration': 2435,
#  'loaded': 5698,
#  'boots': 1655,
#  'tcp': 9213,
#  'ip': 5184,
#  'background': 1392,
#  'unix': 9699,
#  'running': 8134,
#  'mit': 6134,
#  'x11r4': 10205,
#  'sun': 9047,
#  'window': 10091,
#  'ncd': 6344,
#  'manually': 5868,
#  'login': 5718,
#  'telnet': 9253,
#  'session': 8405,
#  'tried': 9545,
#  'xhost': 10219,
#  'failed': 3850,
#  'implementation': 4874,
#  'bogus': 1631,
#  ...}

# %% [markdown]
# Индекс, например, для слова anyone:

# %%
vectorizer.vocabulary_.get('car')
# Out:
# 1905

# %% [markdown]
# А теперь преобразуем строку в вектор:

# %%
text = 'I was wondering if anyone out there could enlighten me on this car I saw'
x = vectorizer.transform([text])

# %% [markdown]
# Какой тип имеет объект, на который указывает ```x```?

# %%
type(x)
# Out:
# scipy.sparse.csr.csr_matrix

# %% [markdown]
# Разреженная матрица!

# %% [markdown]
# ### Отступление про разреженные матрицы

# %% [markdown]
# Список ненулевых элементов матрицы:

# %%
x.data
# Out:
# array([1, 1, 1, 1])

# %% [markdown]
# Индексы строк и столбцов для ненулевых элементов:

# %%
x.nonzero()
# Out:
# (array([0, 0, 0, 0], dtype=int32),
#  array([ 1905,  3576,  8221, 10138], dtype=int32))

# %% [markdown]
# Преобразование к объекту ndarray (именно после приведения к такому виду разреженные матрицы можно подставлять в функции, например, библиотеки Numpy):

# %%
x.toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]])

# %% [markdown]
# Вернемся к словарю. Раскодируем вектор ```x``` в список слов:

# %%
vectorizer.inverse_transform(x)
# Out:
# [array(['car', 'enlighten', 'saw', 'wondering'], dtype='<U79')]

# %% [markdown]
# Пропало слово ```I```. Но дело в том, что по умолчанию ```CountVectorizer``` отбрасывает последовательности, короче 2 символов. На это указывает параметр ```token_pattern='(?u)\\b\\w\\w+\\b'```.

# %% [markdown]
# Переведем весь набор текстов обучающего датасета в набор векторов, получим матрицу ```X_train```:

# %%
X_train = vectorizer.fit_transform(newsgroups_train.data)
X_train.shape
# Out:
# (11314, 10299)

# %% [markdown]
# О пользе разреженных матриц. Отношение числа ненулевых элементов ко всем элементам матрицы ```X_train```:

# %%
X_train.nnz / np.prod(X_train.shape)
# Out:
# 0.004124425823095387

# %% [markdown]
# Задача: запустить модель LDA и Gibbs Sampling с числов тегов 20. Вывести топ-10 слов по каждому тегу. Соотнести полученные теги с тегами из датасета, сделать выводы.

# %%
from tqdm import tqdm

def lda(X, n_topics, alpha, beta, n_iter=10):
    n_kw = np.zeros((n_topics, X.shape[1]))
    n_dk = np.zeros((X.shape[0], n_topics))
    n_k = np.zeros(n_topics)
    
    docs, words = X.nonzero()
    z = np.random.choice(n_topics, len(docs))
    
    for doc, word, cur_z in zip(docs, words, z):
        n_dk[doc, cur_z] += 1
        n_kw[cur_z, word] += 1
        n_k[cur_z] += 1
    
    for cur_iter in tqdm(range(n_iter)):
        for i in range(len(docs)):
            cur_word = words[i]
            cur_doc = docs[i]
            cur_topic = z[i]
            
            n_dk[cur_doc, cur_topic] -= 1
            n_kw[cur_topic, cur_word] -= 1
            n_k[cur_topic] -= 1
            
            p = (n_dk[cur_doc, :] + alpha) * (n_kw[:, cur_word] + beta[cur_word]) / \
                (n_k + beta.sum())
            z[i] = np.random.choice(np.arange(n_topics), p=p / p.sum())
            
            n_dk[cur_doc, z[i]] += 1
            n_kw[z[i], cur_word] += 1
            n_k[z[i]] += 1
    
    return z, n_kw, n_dk, n_k

# %%
n_topics = 20
z, n_kw, n_dk, n_k = lda(X_train, n_topics, 1 * np.ones(n_topics), \
                         1 * np.ones(X_train.shape[1]), 60)
# Out:
# 100%|██████████| 60/60 [22:46<00:00, 22.77s/it]

# %% [markdown]
# _Выведем топ 10 слов для кажой из найденных тем_

# %%
top_words = np.argsort(n_kw, axis=1)[:, :-11:-1]

for topic in range(20):
    doc = np.zeros((1, X_train.shape[1]))
    for word in top_words[topic]:
        doc[0, word] = 1
    print('Topic {}:\t{}'.format(topic, '\t'.join(vectorizer.inverse_transform(doc)[0])))
# Out:
# Topic 0:	clinton	future	general	house	money	national	president	public	states	united
# Topic 1:	came	days	happened	left	night	saw	started	told	took	went
# Topic 2:	bike	buy	car	cars	engine	miles	nice	ride	road	speed
# Topic 3:	country	history	israel	israeli	jewish	jews	land	population	turkish	war
# Topic 4:	chip	clipper	encryption	key	keys	message	phone	public	secure	security
# Topic 5:	comes	common	deal	difference	exactly	major	mentioned	money	quick	small
# Topic 6:	aren	btw	couldn	guess	hey	oh	ok	stuff	talking	yeah
# Topic 7:	article	certainly	current	fault	fine	guess	nice	reasonable	sorry	sounds
# Topic 8:	14	25	40	ca	hp	id	ma	mi	mr	tm
# Topic 9:	application	code	file	files	ftp	running	server	sun	version	window
# Topic 10:	banks	cause	disease	doctor	gordon	medical	pitt	soon	surrender	usually
# Topic 11:	1993	center	date	earth	low	nasa	research	science	space	university
# Topic 12:	11	12	game	games	league	play	players	season	team	win
# Topic 13:	card	computer	disk	mac	memory	monitor	pc	price	sale	video
# Topic 14:	advance	anybody	appreciate	appreciated	greatly	hi	info	reply	thank	wondering
# Topic 15:	control	crime	gun	guns	law	laws	police	rights	self	weapons
# Topic 16:	bible	christ	christian	christians	claim	jesus	religion	saying	says	word
# Topic 17:	100	bob	certainly	ideas	reading	stay	stuff	thinking	vice	yeah
# Topic 18:	anybody	article	cheers	deleted	figure	guess	love	oh	sounds	thank
# Topic 19:	agree	assume	btw	especially	haven	knows	mike	result	sorry	write

# %% [markdown]
# Следующие темы интерпретируемы:
#  - Тема 0 - политика
#  - Тема 2 - дороги, машины
#  - Тема 3 - история, страны
#  - Тема 4 - криптография
#  - Тема 6 - разгоровные выражения
#  - Тема 8 - сокращения из comp.os.ms-windows.misc
#  - Тема 9 - компьютерные приложения
#  - Тема 10 - медицина
#  - Тема 11 - космос
#  - Тема 12 - игры
#  - Тема 13 - части компьютера
#  - Тема 15 - полиция, преступления
#  - Тема 16 - религия
#
# Эти темы есть среди тем из датасета:

# %%
newsgroups_train.target_names
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']
